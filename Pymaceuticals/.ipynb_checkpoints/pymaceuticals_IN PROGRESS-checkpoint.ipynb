# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
combined_df = pd.merge(mouse_metadata,study_results, on="Mouse ID", how="right")
combined_df

# Display the data table for preview
study_df =combined_df[["Mouse ID","Timepoint", "Tumor Volume (mm3)","Metastatic Sites","Drug Regimen", "Sex", "Age_months","Weight (g)"]]
study_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice.
mice_count=mouse_metadata["Mouse ID"].count()
mice_count
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_mice =study_df[study_df.duplicated(['Mouse ID', 'Timepoint'], keep=False)]
duplicate_ids = duplicate_mice['Mouse ID'].unique()
duplicate_ids
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_data = study_df.loc[study_df['Mouse ID'] == 'g989']
duplicate_data
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_df = study_df.drop(study_df.loc[study_df['Mouse ID'] == 'g989'].index)
clean_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice in the clean DataFrame.
count_after_del = len(clean_df['Mouse ID'].unique())
count_after_del
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.
main_df = clean_df.groupby("Drug Regimen")["Tumor Volume (mm3)"]
mean= main_df.mean()
median=main_df.median()
standard_dev = main_df.std()
variance = main_df.var()
standard_err = main_df.sem()

summary_stats = pd.DataFrame({  "Mean Tumor Volume": mean,
                                "Median Tumor Volume": median,
                                "Tumor Volume Variance": variance,
                                "Tumor Volume Std. Dev.": standard_dev,
                                "Tumor Volume Std. Err": standard_err})
summary_stats
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err
# Drug Regimen
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Group the data by "Drug Regimen" and calculate the summary statistics in a single line using .agg()
agg_df = clean_df.groupby("Drug Regimen").agg({"Tumor Volume (mm3)": ["mean","median","var","std","sem"]})
agg_df
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Grouping the data by 'Drug Regimen' and counting the number of rows
regimen_counts = clean_df.groupby('Drug Regimen').size()
regimen_counts = regimen_counts.sort_values(ascending=False)

# Creating the bar plot using pandas
regimen_counts.plot(kind='bar', color="blue")

# Setting the labels and title
plt.xlabel("Drug Regimen")
plt.ylabel("# of Observed Mouse Time Points")


# Displaying the plot
plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.

counts = clean_df.groupby("Drug Regimen").size()
counts = counts.sort_values(ascending=False)
# Create a bar plot
plt.bar(counts.index, counts.values, color ='b')

# Set the x-axis label
plt.xlabel("Drug Regimen")
plt.xticks(rotation="vertical")
# Set the y-axis label
plt.ylabel("# of Observed Mouse Time Points")
plt.show()

# %%
gender_counts=clean_df["Sex"].value_counts()
gender_counts.plot(kind='pie',autopct='%1.1f%%')
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%')
plt.ylabel('Sex')
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
last_timepoint = clean_df.groupby("Mouse ID")["Timepoint"].max().reset_index()
merged_df = pd.merge(clean_df,last_timepoint, on=["Mouse ID", "Timepoint"], how="right")
treatment_list = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]
tumor_volume_data = []
for treatment in treatment_list:
    final_tumor_volumes = merged_df.loc[merged_df["Drug Regimen"] == treatment]["Tumor Volume (mm3)"]
    tumor_volume_data.append(final_tumor_volumes)
tumor_volume_data
# Out:
# [19     38.982878
#  24     38.939633
#  61     30.485985
#  64     37.074024
#  66     40.159220
#  80     47.685963
#  83     37.311846
#  85     38.125164
#  87     38.753265
#  108    41.483008
#  115    38.846876
#  121    28.430964
#  124    33.329098
#  162    46.539206
#  163    32.377357
#  169    41.581521
#  174    23.343598
#  180    40.728578
#  183    34.455298
#  192    31.023923
#  204    40.658124
#  208    39.952347
#  220    36.041047
#  226    28.484033
#  239    31.896238
#  Name: Tumor Volume (mm3), dtype: float64,
#  6      38.407618
#  7      43.047543
#  10     38.810366
#  12     32.978522
#  33     38.342008
#  37     33.397653
#  45     37.311236
#  52     40.659006
#  70     29.128472
#  76     33.562402
#  77     36.374510
#  91     31.560470
#  93     36.134852
#  96     22.050126
#  119    30.564625
#  126    31.095335
#  157    45.220869
#  158    36.561652
#  166    37.225650
#  168    43.419381
#  177    30.276232
#  190    40.667713
# ...

# %%
import numpy as np
index = 0
for treatment in treatment_list:
    values = tumor_volume_data[index]
    
    # Calculate quartiles
    quartiles = np.percentile(values, [25, 50, 75])
    lower_quartile = quartiles[0]
    median = quartiles[1]
    upper_quartile = quartiles[2]
    
    # Calculate IQR
    iqr = upper_quartile - lower_quartile
    
    # Calculate lower and upper bounds
    lower_bound = lower_quartile - 1.5 * iqr
    upper_bound = upper_quartile + 1.5 * iqr
    
    # Find potential outliers for each treatment
    potential_outliers = values[(values < lower_bound) | (values > upper_bound)]
    print(f"{treatment}'s potential outliers: {potential_outliers}")
    print("---------------------------------")
    
    index += 1
# Out:
# Capomulin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# ---------------------------------
# Ramicane's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# ---------------------------------
# Infubinol's potential outliers: 31    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# ---------------------------------
# Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# ---------------------------------

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatment_list = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for i, treatment in enumerate(treatment_list):
    quartiles = tumor_volume_data[i].quantile([0.25, 0.5, 0.75])
    lower_quartile = quartiles[0.25]
    upper_quartile = quartiles[0.75]
    iqr = upper_quartile - lower_quartile
    # Calculate the lower and upper bounds to identify potential outliers.
    lower_bound = lower_quartile - 1.5 * iqr
    upper_bound = upper_quartile + 1.5 * iqr
    # Find potential outliers for each treatment.
    potential_outliers = tumor_volume_data[i][(tumor_volume_data[i] < lower_bound) | (tumor_volume_data[i] > upper_bound)]
 
    print(f"{treatment}'s potential outliers: {potential_outliers}")
# Out:
# Capomulin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's potential outliers: 31    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
treatment_list = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]
data = [tumor_volume_data[i] for i in range(len(treatment_list))]

# Generate the box plot
fig, ax = plt.subplots()
ax.set_ylabel("Final Tumor Volume")
outlier_props = dict(marker='o', markerfacecolor='red', markersize=8)
ax.boxplot(data, labels=treatment_list, flierprops=outlier_props)
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin

# Filter the data
mouse_data = clean_df.loc[clean_df['Mouse ID'] == 'l509', ['Timepoint', 'Tumor Volume (mm3)']]

# Generate the line plot
plt.plot(mouse_data["Timepoint"], mouse_data["Tumor Volume (mm3)"])

# Set the labels and title
plt.xlabel("Timepoint (days)")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Capomulin Treatment of Mouse 1509")

# Show the plot
plt.show()

# %%
# Filter the data for the Capomulin regimen
capomulin_data = clean_df.loc[clean_df["Drug Regimen"] == "Capomulin", ["Weight (g)", "Mouse ID", "Tumor Volume (mm3)"]]

# Group the data first by weight and then within each weight group by mouse ID to find the mean tumor volume
grouped_data = capomulin_data.groupby(["Weight (g)", "Mouse ID"])["Tumor Volume (mm3)"].mean().reset_index()

plt.scatter(grouped_data["Weight (g)"], grouped_data["Tumor Volume (mm3)"])

# Set the labels and title
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")

# Show the plot
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
capomulin_data = clean_df.loc[clean_df["Drug Regimen"] == "Capomulin", ["Weight (g)", "Mouse ID", "Tumor Volume (mm3)"]]
grouped_data = capomulin_data.groupby(["Weight (g)", "Mouse ID"])["Tumor Volume (mm3)"].mean().reset_index()
weight = grouped_data["Weight (g)"]
tumor = grouped_data["Tumor Volume (mm3)"]

correlation = st.pearsonr(weight, tumor)
pe_slope, pe_int, pe_r, pe_p, pe_std_err = st.linregress(weight, tumor)
pe_fit = pe_slope * weight + pe_int
plt.scatter(weight, tumor)
plt.plot(weight, pe_fit, "-", color="red")
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
print(f'The correlation between mouse weight and the average tumor volume is {round(correlation[0],2)}')
plt.show()
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84
